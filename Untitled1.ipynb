# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanthjack/pyton/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing package
import pandas as pd

# %%
stats=pd.read_csv('/content/DemographicData.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#number of rows
len(stats)
# Out:
# 195

# %%
#see columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#number of columns 
len(stats.columns)
# Out:
# 5

# %%
#top rows
stats.head() #number of row can be specified - default is 5
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#information on columns
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#statistics on dataframe
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
  stats.columns = ['countryName', 'countryCode', 'BirthRate', 'InternetUsers', 'Incomegroup']

# %%
stats.head()
# Out:
#             countryName countryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            Incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#subsetting
#rows
stats[20:23]
# Out:
#    countryName countryCode  BirthRate  InternetUsers          Incomegroup
# 20     Belarus         BLR     12.500          54.17  Upper middle income
# 21      Belize         BLZ     23.092          33.60  Upper middle income
# 22     Bermuda         BMU     10.400          95.30          High income

# %%
stats[3:7]
# Out:
#             countryName countryCode  BirthRate  InternetUsers  \
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            Incomegroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
stats.columns[2:4]
# Out:
# Index(['BirthRate', 'InternetUsers'], dtype='object')

# %%
stats[:7] # from beginning to specified rows
# Out:
#             countryName countryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            Incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
stats[188:] #from specified row till the end
# Out:
#             countryName countryCode  BirthRate  InternetUsers  \
# 188  West Bank and Gaza         PSE     30.394           46.6
# 189               Samoa         WSM     26.172           15.3
# 190         Yemen, Rep.         YEM     32.947           20.0
# 191        South Africa         ZAF     20.850           46.5
# 192    Congo, Dem. Rep.         COD     42.394            2.2
# 193              Zambia         ZMB     40.471           15.4
# 194            Zimbabwe         ZWE     35.715           18.5
#
#              Incomegroup
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats[::-1]
# Out:
#               countryName countryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              Incomegroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
#column subsetting

# %%
stats['countryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: countryName, dtype: object

# %%
stats[['BirthRate', 'countryName']].head()
# Out:
#    BirthRate           countryName
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
stats.countryCode.head()
# Out:
# 0    ABW
# 1    AFG
# 2    AGO
# 3    ALB
# 4    ARE
# Name: countryCode, dtype: object

# %%
#subsetting Rows & columns
stats[4:8][['BirthRate', 'countryName']]
# Out:
#    BirthRate           countryName
# 4     11.044  United Arab Emirates
# 5     17.716             Argentina
# 6     13.308               Armenia
# 7     16.447   Antigua and Barbuda

# %%
stats[['BirthRate','countryName']][4:8]
# Out:
#    BirthRate           countryName
# 4     11.044  United Arab Emirates
# 5     17.716             Argentina
# 6     13.308               Armenia
# 7     16.447   Antigua and Barbuda

# %%
result = stats.InternetUsers / stats.BirthRate

# %%
result.head()
# Out:
# 0    7.702070
# 1    0.167362
# 2    0.415353
# 3    4.442028
# 4    7.968127
# dtype: float64

# %%
stats['NewColumn'] = stats.InternetUsers / stats.BirthRate

# %%
stats.head()
# Out:
#             countryName countryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            Incomegroup  NewColumn
# 0          High income   7.702070
# 1           Low income   0.167362
# 2  Upper middle income   0.415353
# 3  Upper middle income   4.442028
# 4          High income   7.968127

# %%
newstats = stats.drop('NewColumn', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
newstats.head()
# Out:
#             countryName countryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            Incomegroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#filtering Data Frames
#filtering is about rows

# %%
filter = stats.InternetUser < 2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-5c52d9e25133> in <module>
# ----> 1 filter = stats.InternetUser < 2
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'InternetUser'

# %%
#multiple filters 
stats[stats.internetUsers < 2) & (stats.birthrate> 40)
# Out:
#   File "<ipython-input-47-7523d1d79811>", line 2
#     stats[stats.internetUsers < 2) & (stats.birthrate> 40)
#                                  ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 8,8
import warnings
warnings.filterwarnings('ignore')

# %%
#distribution
sns.distplot(stats['InternetUsers'])

# %%
sns.distplot(stats['InternetUsers'], bins = 40)

# %%
#boxplot
visualbox1 = sns.boxplot(data = stats, x = "Incomegroup", y = "BirthRate")
plt.rcParams['figure.figsize'] = 8,4

# %%
visual4 = sns.lmplot(data=stats, x = 'InternetUsers', y = "BirthRate", fit_reg = False, hue='Incomegroup', size = 8, aspect = 1, scatter_kws = {'s' = 200})
# Out:
#   File "<ipython-input-58-52af1aef4ce7>", line 1
#     visual4 = sns.lmplot(data=stats, x = 'InternetUsers', y = "BirthRate", fit_reg = False, hue='Incomegroup', size = 8, aspect = 1, scatter_kws = {'s' = 200})
#                                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
stats.to_excel("output.xlsx")
